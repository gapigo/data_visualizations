# %%
from imports import *
df = pd.read_csv('../data/mpg_ggplot2.csv')

# filter only 2 classes
df = df[df['cyl'].isin([4,8])]

# plot the data using seaborn
sns.lmplot(x='displ', y='hwy', data=df, hue='cyl')
plt.grid()
