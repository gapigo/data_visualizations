# %%
from imports import *
df = pd.DataFrame({
    'sales': [6, 4, 9, 7, 13, 10],
    'signups': [9, 13, 15, 12, 20, 26],
    'visits': [20, 42, 28, 62, 81, 50]
}
                  , index=pd.date_range(start='2024/05/01', end='2024/11/01', freq='M'))

ax = df.plot.area()
